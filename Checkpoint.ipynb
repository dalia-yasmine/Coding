# %% [markdown]
# <a href="https://colab.research.google.com/github/dalia-yasmine/Coding/blob/main/Checkpoint.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
nombre = random.randint(0, 1)
print("Pile ou")
if nombre == 0:
  print("Pile")
else:
  print("Face")
# Out:
# Pile ou
# Face
