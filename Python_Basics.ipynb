# %% [markdown]
# <a href="https://colab.research.google.com/github/dalia-yasmine/Coding/blob/main/Python_Basics.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Exemple : Python Syntax basics
print("Hello, World!")  # printing a message

# Indentation defines blocks
if True:
    print("This is inside the if block")
    print("Still inside")

print("This is outside")
# Out:
# Hello, World!
# This is inside the if block
# Still inside
# This is outside

# %%
#Coding my name and my age
print("Dalia Hakiki")
print("17")
# Out:
# Dalia Hakiki
# 17

# %%
#Example
student_name = "Alice"    #variable
student_age = 20

PI = 3.14159              #constant (by convention)
MAX_SCORE = 100

print(student_name, student_age)
print("le prenom est :",student_name,", l'age est :",student_age)
print(PI, MAX_SCORE)
# Out:
# Alice 20
# le prenom est : Alice , l'age est : 20
# 3.14159 100

# %%
#writing a paragraph with print
print("Coucou \nJe meurs de faim \nYara nourris moi")
# Out:
# Coucou
# Je meurs de faim
# Yara nourris moi

# %%
#create variables and constants
first_name = "Dalia"    #variable
last_name = "Hakiki"
age = 17

WEEK = 7                #constant

print("My name is :",first_name, last_name)
print("I am :",age)
print("We have",week,"days in a week")
# Out:
# My name is : Dalia Hakiki
# I am : 17
# We have 7 days in a week

# %%
#modifiate the value of a variable
score = 0
print("Initial score :", score)

score = 10            #reassigment
print("New score :", score)

score+= 5            #augmented: score = score + 5
print("After +5 :", score)

a, b, c = 1, 2, 3    #multiple assigment
'''
a = 1
b = 2
c = 3
'''
print(a, b, c)
# Out:
# Initial score : 0
# New score : 10
# After +5 : 15
# 1 2 3

# %%
#exercice
lives = 3
print("Total of lives:", lives)

lives-= 1
print("\nAfter losing 1 live:", lives)

lives-= 1
print("After losing another live:", lives)

lives+= 2
print("Final total of lives", lives)
# Out:
# Total of lives: 3
#
# After losing 1 live: 2
# After losing another live: 1
# Final total of lives 3
